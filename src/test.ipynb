# %%
import pandas

# %%
from kmeans_model import train

# %%
colleges = train()

# %%
colleges
# Out:
#                                 NAME Private  F.Undergrad    Expend  \
# 0                Agnes Scott College       1     0.009890  0.291024
# 1          Alaska Pacific University       1     0.000000  0.136835
# 2            Albertus Magnus College       1     0.006328  0.097573
# 3                     Albion College       1     0.050964  0.147598
# 4                       Alma College       1     0.040052  0.106031
# ..                               ...     ...          ...       ...
# 342            Wittenberg University       1     0.065591  0.127157
# 343                  Wofford College       1     0.030692  0.078790
# 344  Worcester Polytechnic Institute       1     0.096738  0.134015
# 346   Xavier University of Louisiana       1     0.096396  0.087324
# 347                  Yale University       1     0.188246  0.698118
#
#      stem_percent     Women  acceptance_rate     top10  grad_rate  \
# 0            0.26  0.993127         0.836930  0.437956       0.59
# ...

# %%
from kmeans_model import find_colleges

# %%
output = find_colleges(colleges=colleges, name="Yale University")

# %%
output
# Out:
#                          NAME  Private  F.Undergrad  Expend  stem_percent  \
# 96         Harvard University        1         6862   37219          0.19
# 113  Johns Hopkins University        1         3566   56233          0.31
# 300    Wake Forest University        1         3499   41766          0.13
#
#         Women  acceptance_rate     top10  grad_rate  diversity_score      SAT%
# 96   0.485186         0.156149  0.056040       1.00         0.543746  0.956250
# 113  0.519792         0.406656  0.082327       0.90         0.523863  0.946875
# 300  0.512583         0.422540  0.083056       0.89         0.286852  0.890625
