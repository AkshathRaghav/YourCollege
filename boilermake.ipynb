# %% [markdown]
# <a href="https://colab.research.google.com/github/AkshathRaghav/boilermake2023/blob/main/boilermake.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd

# %%
# !gdown https://drive.google.com/drive/folders/1M3vtSt4sBwJOADYbszQzEXacRMQz14mK?usp=sharing
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/parse_url.py:35: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/drive/folders/1M3vtSt4sBwJOADYbszQzEXacRMQz14mK?usp=sharing
# To: /content/1M3vtSt4sBwJOADYbszQzEXacRMQz14mK?usp=sharing
# 936kB [00:00, 72.5MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
salary = pd.read_csv('/content/drive/MyDrive/boilermake2023/data/salary_potential.csv')
main_data = pd.read_csv('/content/drive/MyDrive/boilermake2023/data/College_Data.csv')

# %%
salary
# Out:
#      rank                                 name state_name  early_career_pay  \
# 0       1                    Auburn University    Alabama             54400
# 1       2  University of Alabama in Huntsville    Alabama             57500
# 2       3            The University of Alabama    Alabama             52300
# 3       4                  Tuskegee University    Alabama             54500
# 4       5                   Samford University    Alabama             48400
# ..    ...                                  ...        ...               ...
# 930    22                   Viterbo University  Wisconsin             46800
# 931    23       Concordia University-Wisconsin  Wisconsin             46700
# 932    24     University of Wisconsin-Parkside  Wisconsin             46000
# 933    25  University of Wisconsin-River Falls  Wisconsin             47100
# 934     1                University of Wyoming    Wyoming             52400
#
# ...

# %%
salary.drop('make_world_better_percent', axis=1)
# Out:
#      rank                                 name state_name  early_career_pay  \
# 0       1                    Auburn University    Alabama             54400
# 1       2  University of Alabama in Huntsville    Alabama             57500
# 2       3            The University of Alabama    Alabama             52300
# 3       4                  Tuskegee University    Alabama             54500
# 4       5                   Samford University    Alabama             48400
# ..    ...                                  ...        ...               ...
# 930    22                   Viterbo University  Wisconsin             46800
# 931    23       Concordia University-Wisconsin  Wisconsin             46700
# 932    24     University of Wisconsin-Parkside  Wisconsin             46000
# 933    25  University of Wisconsin-River Falls  Wisconsin             47100
# 934     1                University of Wyoming    Wyoming             52400
#
#      mid_career_pay  stem_percent
# ...

# %%
main_data
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %%
main_data.rename(columns = {"Unnamed: 0":"name"}, inplace=True)

# %%
a = salary.iloc[:,1].values.tolist()
b = main_data.iloc[:,0].values.tolist()

# %%
remaining = list(set(b)-set(a))
len(remaining)
# Out:
# 419

# %%
for i in remaining: 
  try: 
    print(salary[salary['name'] == i].index.tolist()[0])
    salary.drop(salary[salary['name'] == i].index.tolist()[0], axis=0,inplace=True)
  except:
    try: 
      main_data.drop(main_data[main_data['name'] == i].index.tolist()[0],axis=0,inplace=True)
    except: 
      print(i)

# %%
len(main_data)
# Out:
# 358

# %%
len(salary)
# Out:
# 935

# %%
main_data
# Out:
#                                 name Private   Apps  Accept  Enroll  \
# 3                Agnes Scott College     Yes    417     349     137
# 4          Alaska Pacific University     Yes    193     146      55
# 6            Albertus Magnus College     Yes    353     340     103
# 7                     Albion College     Yes   1899    1720     489
# 13                      Alma College     Yes   1267    1080     385
# ..                               ...     ...    ...     ...     ...
# 770                  Wofford College     Yes   1501     935     273
# 771  Worcester Polytechnic Institute     Yes   2768    2314     682
# 773                Xavier University     Yes   1959    1805     695
# 774   Xavier University of Louisiana     Yes   2097    1915     695
# 775                  Yale University     Yes  10705    2453    1317
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 3           60         89          510           63     12960        5450
# ...

# %%
b2 = main_data.iloc[:,0].values.tolist()
remaining2 = list(set(a)-set(b2))
remaining2
# Out:
# ['Lewis-Clark State College',
#  'Rush University',
#  'Oregon Health & Science University',
#  'Pace University-New York',
#  'Barton College',
#  "St Mary's College of Maryland",
#  'Virginia Polytechnic Institute and State University',
#  'Colby-Sawyer College',
#  'University of the Sciences',
#  'University of New Haven',
#  'Pacific Northwest College of Art',
#  'Clark Atlanta University',
#  'Cleary University',
#  'The University of Texas Health Science Center at San Antonio',
#  'Haverford College',
#  'Clarke University',
#  'Rice University',
#  'Baptist Memorial College of Health Sciences',
#  'Rhode Island School of Design',
#  'Campbellsville University',
#  'The University of Tennessee at Knoxville',
#  'Vermont Technical College',
#  'Kentucky State University',
#  'Golden Gate University',
#  'Indiana University -Purdue U. at Fort Wayne',
#  'University of Toledo',
#  'Western New Mexico University',
#  'Austin Peay State University',
#  'Oakwood University',
# ...

# %%
for i in remaining2: 
  try: 
    print(salary[salary['name'] == i].index.tolist()[0])
    salary.drop(salary[salary['name'] == i].index.tolist()[0], axis=0,inplace=True)
  except:
    try: 
      main_data.drop(main_data[main_data['name'] == i].index.tolist()[0],axis=0,inplace=True)
    except: 
      print(i)
# Out:
# 185
# 190
# 672
# 588
# 613
# 361
# 844
# 529
# 703
# 108
# 686
# 165
# 422
# 806
# 705
# 255
# 792
# 771
# 724
# 309
# 773
# 831
# 303
# 77
# 234
# 641
# 563
# 787
# 14
# 111
# 608
# 877
# 53
# 751
# 737
# 741
# 574
# 579
# 540
# 553
# 602
# 304
# 566
# 272
# 495
# 147
# 643
# 171
# 269
# 813
# 173
# 345
# 550
# 384
# 557
# 284
# 207
# 715
# 868
# 555
# 408
# 834
# 37
# 897
# 585
# 296
# 5
# 519
# 428
# 1
# 423
# 762
# 833
# 51
# 765
# 68
# 168
# 457
# 245
# 120
# 722
# 782
# 418
# 301
# 169
# 569
# 654
# 825
# 358
# 180
# 381
# 508
# 85
# 730
# 366
# 537
# 115
# 251
# 330
# 798
# 362
# 50
# 903
# 425
# 12
# 896
# 645
# 323
# 233
# 780
# 20
# 6
# 437
# 257
# 268
# 395
# 858
# 512
# 134
# 854
# 509
# 891
# 315
# 498
# 907
# 406
# 573
# 601
# 683
# 438
# 859
# 55
# 513
# 287
# 665
# 33
# 885
# 657
# 352
# 763
# 482
# 317
# 334
# 112
# 363
# 922
# 666
# 692
# 96
# 122
# 931
# 551
# 230
# 11
# 930
# 729
# 176
# 779
# 160
# 532
# 95
# 195
# 902
# 655
# 93
# 908
# 23
# 775
# 41
# 556
# ...

# %%
salary
# Out:
#      rank                                   name state_name  early_career_pay  \
# 0       1                      Auburn University    Alabama             54400
# 3       4                    Tuskegee University    Alabama             54500
# 4       5                     Samford University    Alabama             48400
# 7       8    University of Alabama at Birmingham    Alabama             48600
# 13     14                     Huntingdon College    Alabama             42400
# ..    ...                                    ...        ...               ...
# 920    12  University of Wisconsin at Whitewater  Wisconsin             48900
# 925    17                         Beloit College  Wisconsin             47400
# 926    18                       Carthage College  Wisconsin             48900
# 929    20             Wisconsin Lutheran College  Wisconsin             46200
# 934     1                  University of Wyoming    Wyoming             52400
#
# ...

# %%
a3 = salary.iloc[:,1].values.tolist()
b3 = main_data.iloc[:,0].values.tolist()
final_remaining = list(set(a3)-set(b3))
len(final_remaining)
# Out:
# 1

# %%
main_data.sort_values('name')
# Out:
#                                 name Private   Apps  Accept  Enroll  \
# 3                Agnes Scott College     Yes    417     349     137
# 4          Alaska Pacific University     Yes    193     146      55
# 6            Albertus Magnus College     Yes    353     340     103
# 7                     Albion College     Yes   1899    1720     489
# 13                      Alma College     Yes   1267    1080     385
# ..                               ...     ...    ...     ...     ...
# 770                  Wofford College     Yes   1501     935     273
# 771  Worcester Polytechnic Institute     Yes   2768    2314     682
# 773                Xavier University     Yes   1959    1805     695
# 774   Xavier University of Louisiana     Yes   2097    1915     695
# 775                  Yale University     Yes  10705    2453    1317
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 3           60         89          510           63     12960        5450
# ...

# %%
salary = salary.sort_values('name')

# %%
main_data
# Out:
#                                 name Private   Apps  Accept  Enroll  \
# 3                Agnes Scott College     Yes    417     349     137
# 4          Alaska Pacific University     Yes    193     146      55
# 6            Albertus Magnus College     Yes    353     340     103
# 7                     Albion College     Yes   1899    1720     489
# 13                      Alma College     Yes   1267    1080     385
# ..                               ...     ...    ...     ...     ...
# 770                  Wofford College     Yes   1501     935     273
# 771  Worcester Polytechnic Institute     Yes   2768    2314     682
# 773                Xavier University     Yes   1959    1805     695
# 774   Xavier University of Louisiana     Yes   2097    1915     695
# 775                  Yale University     Yes  10705    2453    1317
#
#      Top10perc  Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  \
# 3           60         89          510           63     12960        5450
# ...

# %%
salary
# Out:
#      rank                             name      state_name  early_career_pay  \
# 161    14              Agnes Scott College         Georgia             46000
# 27      3        Alaska Pacific University          Alaska             50300
# 116    18          Albertus Magnus College     Connecticut             49700
# 407     7                   Albion College        Michigan             52100
# 415    15                     Alma College        Michigan             48400
# ..    ...                              ...             ...               ...
# 735     4                  Wofford College  South Carolina             51300
# 378     3  Worcester Polytechnic Institute   Massachusetts             73600
# 639    16                Xavier University            Ohio             51800
# 322    11   Xavier University of Louisiana       Louisiana             46700
# 98      1                  Yale University     Connecticut             70300
#
# ...

# %%
main_data.to_csv('/content/drive/MyDrive/boilermake2023/data/main_data.csv', index=False)
salary.to_csv('/content/drive/MyDrive/boilermake2023/data/salary_data.csv', index=False)

diversity = pd.read_csv("/content/drive/MyDrive/boilermake2023/data/cleaned_diversity_school.csv")

# %%
result = pd.merge(main_data, salary, how="left", on=['name'])
final_result = pd.merge(result, diversity, how="left", on=['name'])

# %%
final_result.to_csv("/content/drive/MyDrive/boilermake2023/data/3dfsMerged.csv", index=False)

# %%
test = pd.read_csv("/content/finalcollegenames.csv", encoding="")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-145-fd290376f8bd> in <module>
# ----> 1 test = pd.read_csv("/content/finalcollegenames.csv")
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
